# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
oversampled_train = pd.read_csv('oversampled_train.csv')
#oversampled_train = pd.read_csv('oversampled_train_05.csv')
#oversampled_train = pd.read_csv('oversampled_train_not_majorty.csv')

# %%
sns.set_style('whitegrid')
oversampled_train['y'].hist(bins=30)
plt.xlabel('y')
# Out:
# Text(0.5, 0, 'y')

# %%
sns.set_style('whitegrid')
oversampled_train['default'].hist(bins=30)
plt.xlabel('default')
# Out:
# Text(0.5, 0, 'default')

# %%
sns.set_style('whitegrid')
oversampled_train['poutcome'].hist(bins=30)
plt.xlabel('poutcome')
# Out:
# Text(0.5, 0, 'poutcome')

# %%
sns.set_style('whitegrid')
oversampled_train['loan'].hist(bins=30)
plt.xlabel('loan')
# Out:
# Text(0.5, 0, 'loan')

# %%
oversampled_train['contact'].unique()
# Out:
# array([9, 1, 2, 6, 3, 7, 8, 5, 4], dtype=int64)

# %%
sns.set_style('whitegrid')
oversampled_train['contact'].hist(bins=30)
plt.xlabel('contact')
# Out:
# Text(0.5, 0, 'contact')

# %%
fig, ax = plt.subplots(figsize=(20,10))         
# Imbalanced DataFrame Correlation
corr = oversampled_train.corr()
sns.heatmap(corr, cmap='YlGnBu', annot_kws={'size':30}, ax=ax)
ax.set_title("Imbalanced Correlation Matrix", fontsize=14)
plt.show()
